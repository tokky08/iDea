# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup


# ブラウザを操作するオブジェクトの生成
driver = webdriver.Chrome("driver/chromedriver")
# 指定したURLへの移動
driver.get("https://google.co.jp")

value = input()

# 検索窓にSeleniumと入力する
selector = '#tsf > div:nth-child(2) > div.A8SBwf > div.RNNXgb > div > div.a4bIc > input'
element = driver.find_element_by_css_selector(selector)
element.send_keys(value)

# enterキーを押す
element.send_keys(Keys.ENTER)


# ページのHTMLを取得
html = driver.page_source
# ブラウザの終了
driver.close()

# 取得したHTMLからBeautifulSoupオブフェクトを生成
# scriptやstyle及びその他タグの除去
soup = BeautifulSoup(html, "lxml")
for s in soup(['script', 'style']):
    s.decompose()

text = ' '.join(soup.stripped_strings)

print(text)
print(type(text))
# Out:
#  海
# 海 - Google 検索 ユーザー補助のリンク メイン コンテンツにスキップ ユーザー補助ヘルプ ユーザー補助に関するフィードバック 数秒たってもリダイレクトされない場合は、 ここをクリック してください。 ログイン 削除 不適切な検索候補の報告 検索モード すべて 画像 地図 動画 ニュース もっと見る ショッピング 書籍 フライト ファイナンス 設定 検索設定 言語 (Languages) セーフサーチをオンにする 検索オプション 検索アクティビティ 検索におけるデータ ヘルプを検索 ツール すべての言語 すべての言語 日本語のページを検索 期間指定なし 期間指定なし 1 時間以内 24 時間以内 1 週間以内 1 か月以内 1 年以内 期間を指定 期間を指定 開始日: 終了日: 選択 すべての結果 すべての結果 完全一致 約 1,420,000,000 件 （0.37 秒） 検索結果 訪れたことのある場所の確認 Turn on Google Account settings to track places you visit. Turn on Location History to track places you visit. 訪れた場所をトラッキングするには、ウェブとアプリのアクティビティを有効にしてください。 キャンセル OK ローカル検索の結果 評価 指定なし 4.5 以上 4.0 以上 3.5 以上 3.0 以上 2.5 以上 2.0 以上 時間 指定なし 現在営業中 24 時間営業 日 月 火 水 木 金 土 指定なし 0:00 1:00 2:00 3:00 4:00 5:00 6:00 7:00 8:00 9:00 10:00 11:00 12:00 13:00 14:00 15:00 16:00 17:00 18:00 19:00 20:00 21:00 22:00 23:00 営業時間や提供サービスが実際とは異なる場合があります。 海鮮料理 海 3.9 (32) · 魚介料理 京都府京都市 営業時間外 ⋅ 営業開始: 18:00 居心地が良い · グループ · 宅配サービスなし 海遊館 4.4 (29,253) · 水族館 大阪府大阪市 営業時間外 ⋅ 営業開始: 10:30 海洋生物を展示する巨大ランドマーク 岩の海 3.9 (45) · 安価 · ちゃんこ料理店 京都府京都市 営業時間外 ⋅ 営業開始: 5:30 居心地が良い · カジュアル · 子供向き さらに表示 ウェブ検索結果 海 - Wikipedia ja.wikipedia.org › wiki › 海 ja.wikipedia.org › wiki › 海 キャッシュ 類似ページ 海 （